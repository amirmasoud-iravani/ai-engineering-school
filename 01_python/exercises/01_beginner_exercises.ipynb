# %% [markdown]
# # Beginner exercises
#
# Try each task before opening the solution notebook.

# %% [markdown]
# ## 1. Variables
# Create `name`, `field`, and `year`, then print one sentence.

# %%
# Write your code here

# %% [markdown]
# ## 2. Strings
# Clean `"  Persian NLP  "`, make it lowercase, and replace the space with `_`.

# %%
# Write your code here

# %% [markdown]
# ## 3. Lists
# Add `"PyTorch"` to `tools`, remove `"Excel"`, and sort the result.

# %%
tools = ["Python", "Excel", "Git"]
# Write your code here

# %% [markdown]
# ## 4. Dictionaries
# Create a model dictionary with `name`, `task`, and `score`. Add `version=1`.

# %%
# Write your code here

# %% [markdown]
# ## 5. Sets
# Find the shared tools in two skill sets.

# %%
skills_a = {"Python", "pandas", "Git"}
skills_b = {"Python", "PyTorch", "Git"}
# Write your code here

# %% [markdown]
# ## 6. Operators
# Check whether accuracy is at least 0.90 and latency is below 100.

# %%
accuracy = 0.92
latency_ms = 85
# Write your code here

# %% [markdown]
# ## 7. Condition
# Print `deploy` when score >= 0.90, otherwise print `improve`.

# %%
score = 0.88
# Write your code here

# %% [markdown]
# ## 8. Loop
# Print each token and its length.

# %%
tokens = ["هوش", "مصنوعی", "فارسی"]
# Write your code here

# %% [markdown]
# ## 9. Function
# Write `word_count(text)`.

# %%
# Write your code here

# %% [markdown]
# ## 10. File
# Write two Persian lines to a UTF-8 file, then read them.

# %%
# Write your code here
